# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/SATARA_MAY2023-JULY2023_Updated.csv')
data.head()
# Out:
#   Month  Days  YEAR        Date  Min_Temperature  Temperature  \
# 0   May     1  2023  01-05-2023            16.69        20.71
# 1   May     2  2023  02-05-2023            17.34        19.51
# 2   May     3  2023  03-05-2023            13.88        21.78
# 3   May     4  2023  04-05-2023            11.23        21.81
# 4   May     5  2023  05-05-2023            12.65        21.56
#
#    Max_Temperature  Humidity  Precipitation  Surface_Pressure  Wind_speed
# 0            37.40     11.05           0.04             93.45        2.87
# 1            36.84     11.23           0.00             93.52        3.23
# 2            35.66     13.31           0.36             93.65        2.59
# 3            33.04     13.06           0.30             93.61        2.30
# 4            34.21     12.45           0.21             93.52        2.84

# %%
data.shape
# Out:
# (90, 11)

# %%
data.drop(['Surface_Pressure'], axis = 1, inplace = True)
data.head()
# Out:
#   Month  Days  YEAR        Date  Min_Temperature  Temperature  \
# 0   May     1  2023  01-05-2023            16.69        20.71
# 1   May     2  2023  02-05-2023            17.34        19.51
# 2   May     3  2023  03-05-2023            13.88        21.78
# 3   May     4  2023  04-05-2023            11.23        21.81
# 4   May     5  2023  05-05-2023            12.65        21.56
#
#    Max_Temperature  Humidity  Precipitation  Wind_speed
# 0            37.40     11.05           0.04        2.87
# 1            36.84     11.23           0.00        3.23
# 2            35.66     13.31           0.36        2.59
# 3            33.04     13.06           0.30        2.30
# 4            34.21     12.45           0.21        2.84

# %%
# missing columns
data.isna().sum()
# Out:
# Month              0
# Days               0
# YEAR               0
# Date               0
# Min_Temperature    0
# Temperature        0
# Max_Temperature    0
# Humidity           0
# Precipitation      0
# Wind_speed         0
# dtype: int64

# %%
data.describe()
# Out:
#             Days    YEAR  Min_Temperature  Temperature  Max_Temperature  \
# count  90.000000    90.0        90.000000    90.000000        90.000000
# mean   45.500000  2023.0         8.456444    22.237222        30.693000
# std    26.124701     0.0         4.536464     0.899193         4.703953
# min     1.000000  2023.0         1.540000    19.510000        23.730000
# 25%    23.250000  2023.0         4.207500    21.642500        25.847500
# 50%    45.500000  2023.0         8.425000    22.265000        31.035000
# 75%    67.750000  2023.0        12.492500    22.857500        34.925000
# max    90.000000  2023.0        17.340000    24.470000        38.700000
#
#         Humidity  Precipitation  Wind_speed
# count  90.000000      90.000000   90.000000
# mean   16.625444      15.802444    2.993444
# std     1.779128      19.610164    0.774807
# min    11.050000       0.000000    1.050000
# 25%    15.532500       0.950000    2.507500
# 50%    17.330000       7.975000    2.935000
# ...

# %% [markdown]
# **Humidity** (Create a pivot table to aggregate humidity by date & Heatmap Using Seaborn)

# %%
humidity_table = pd.pivot_table(data, values='Humidity', index=['Days'])
sns.heatmap(data = humidity_table, cmap='Reds')
# Out:
# <Axes: ylabel='Days'>

# %% [markdown]
# Temperature

# %%
Temperature_table = pd.pivot_table(data, values='Temperature', index=['Days'])
sns.heatmap(data = Temperature_table, cmap='Oranges')
# Out:
# <Axes: ylabel='Days'>

# %% [markdown]
# Precipitation

# %%
Precipitation_table = pd.pivot_table(data, values='Precipitation', index=['Days'])
sns.heatmap(data = Precipitation_table, cmap='Blues')
# Out:
# <Axes: ylabel='Days'>

# %%
indices = ['Temperature', 'Humidity', 'Precipitation','Wind_speed']
ex_data = data.loc[:,indices]
ex_data
# Out:
#     Temperature  Humidity  Precipitation  Wind_speed
# 0         20.71     11.05           0.04        2.87
# 1         19.51     11.23           0.00        3.23
# 2         21.78     13.31           0.36        2.59
# 3         21.81     13.06           0.30        2.30
# 4         21.56     12.45           0.21        2.84
# ..          ...       ...            ...         ...
# 85        21.31     17.58          38.60        3.10
# 86        21.64     17.82          40.31        4.95
# 87        21.92     17.82          38.54        1.65
# 88        21.58     17.58          19.89        3.20
# 89        21.43     17.40          15.15        3.62
#
# [90 rows x 4 columns]
